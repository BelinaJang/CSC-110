# %% [markdown]
# # CSC 110, Spring 2020
#
#
# ## Assignment 4, part A
#
#
# **Due: Monday, March 9, 2020, 9:00 am (via submission to conneX)**

# %%
# Please change the two comment lines below to indicate your name & student number.
# Name: Belina Jang
# Student #: V00924202

# %% [markdown]
# # Important Note
#
# This is the first part (part A) of a two-part assignment. The second part (part B) is in the file named ```assign04_b.ipynb```.
#
# ### Introduction
#
# In this assignment you will write some Python statements within this Jupyter Notebook that are answers to the posed programming questions. By saving what you have written into the notebook, and submitting the resulting IPython file via conneX, the teaching team will be able to evaluate your work.
#
# You are encouraged to create your own notebooks in order to experiment with programming ideas. Once you have solutions that you wish to submit, they can be copy-and-pasted into this notebook. You should, however, always ensure your Python statements do work by evaluating them within this notebook.
#
# ### Looking up championship winners
#
# This first part of the assignment will take you to the Ireland where they play the sport of **hurling** (links: [Wikipedia](https://en.wikipedia.org/wiki/Hurling), [Youtube](https://www.youtube.com/watch?v=3BVIlpPy8Yc)). Many folks in that country are *very* passionate about the game, and each year a highlight of the sporting season is the **All-Ireland Finals**. Consider it a bit like "Stanley Cup" of hurling. You will write a function to help look up winners of the finals.
#
# In the cell below is a list of tuples, where each tuple is of the form ```(year, province, county)``` or ```(int, str, str)```. The data contained in the list is of All-Ireland Finals winners since 1887. (The data was obtained from [wikipedia](https://en.wikipedia.org/wiki/List_of_All-Ireland_Senior_Hurling_Championship_winners)).
#
# If you use shift-enter within that cell, the list will become part of this notebook's variable definitions and will afterards be accessible in any other code cell.

# %%
ALL_IRELAND_WINNERS = [(1887, "Munster", "Tipperary"), (1889, "Leinster", "Dublin"), (1890, "Munster", "Cork"),
    (1891, "Munster", "Kerry"), (1892, "Munster", "Cork"), (1893, "Munster", "Cork"),
    (1894, "Munster", "Cork"), (1895, "Munster", "Tipperary"), (1896, "Munster", "Tipperary"),
    (1897, "Munster", "Limerick"), (1898, "Munster", "Tipperary"), (1899, "Munster", "Tipperary"),
    (1900, "Munster", "Tipperary"), (1901, "Britain", "London"), (1902, "Munster", "Cork"),
    (1903, "Munster", "Cork"), (1904, "Leinster", "Kilkenny"), (1905, "Leinster", "Kilkenny"),
    (1906, "Munster", "Tipperary"), (1907, "Leinster", "Kilkenny"), (1908, "Munster", "Tipperary"),
    (1909, "Leinster", "Kilkenny"), (1910, "Leinster", "Wexford"), (1911, "Leinster", "Kilkenny"),
    (1912, "Leinster", "Kilkenny"), (1913, "Leinster", "Kilkenny"), (1914, "Munster", "Clare"),
    (1915, "Leinster", "Laois"), (1916, "Munster", "Tipperary"), (1917, "Leinster", "Dublin"),
    (1918, "Munster", "Limerick"), (1919, "Munster", "Cork"), (1920, "Leinster", "Dublin"),
    (1921, "Munster", "Limerick"), (1922, "Leinster", "Kilkenny"), (1923, "Connacht", "Galway"),
    (1924, "Leinster", "Dublin"), (1925, "Munster", "Tipperary"), (1926, "Munster", "Cork"),
    (1927, "Leinster", "Dublin"), (1928, "Munster", "Cork"), (1929, "Munster", "Cork"),
    (1930, "Munster", "Tipperary"), (1931, "Munster", "Cork"), (1932, "Leinster", "Kilkenny"),
    (1933, "Leinster", "Kilkenny"), (1934, "Munster", "Limerick"), (1935, "Leinster", "Kilkenny"),
    (1936, "Munster", "Limerick"), (1937, "Munster", "Tipperary"), (1938, "Leinster", "Dublin"),
    (1939, "Leinster", "Kilkenny"), (1940, "Munster", "Limerick"), (1941, "Munster", "Cork"),
    (1942, "Munster", "Cork"), (1943, "Munster", "Cork"), (1944, "Munster", "Cork"),
    (1945, "Munster", "Tipperary"), (1946, "Munster", "Cork"), (1947, "Leinster", "Kilkenny"),
    (1948, "Munster", "Waterford"), (1949, "Munster", "Tipperary"), (1950, "Munster", "Tipperary"),
    (1951, "Munster", "Tipperary"), (1952, "Munster", "Cork"), (1953, "Munster", "Cork"),
    (1954, "Munster", "Cork"), (1955, "Leinster", "Wexford"), (1956, "Leinster", "Wexford"),
    (1957, "Leinster", "Kilkenny"), (1958, "Munster", "Tipperary"), (1959, "Munster", "Waterford"),
    (1960, "Leinster", "Wexford"), (1961, "Munster", "Tipperary"), (1962, "Munster", "Tipperary"),
    (1963, "Leinster", "Kilkenny"), (1964, "Munster", "Tipperary"), (1965, "Munster", "Tipperary"),
    (1966, "Munster", "Cork"), (1967, "Leinster", "Kilkenny"), (1968, "Leinster", "Wexford"),
    (1969, "Leinster", "Kilkenny"), (1970, "Munster", "Cork"), (1971, "Munster", "Tipperary"),
    (1972, "Leinster", "Kilkenny"), (1973, "Munster", "Limerick"), (1974, "Leinster", "Kilkenny"),
    (1975, "Leinster", "Kilkenny"), (1976, "Munster", "Cork"), (1977, "Munster", "Cork"),
    (1978, "Munster", "Cork"), (1979, "Leinster", "Kilkenny"), (1980, "Connacht", "Galway"),
    (1981, "Leinster", "Offaly"), (1982, "Leinster", "Kilkenny"), (1983, "Leinster", "Kilkenny"),
    (1984, "Munster", "Cork"), (1985, "Leinster", "Offaly"), (1986, "Munster", "Cork"),
    (1987, "Connacht", "Galway"), (1988, "Connacht", "Galway"), (1989, "Munster", "Tipperary"),
    (1990, "Munster", "Cork"), (1991, "Munster", "Tipperary"), (1992, "Leinster", "Kilkenny"),
    (1993, "Leinster", "Kilkenny"), (1994, "Leinster", "Offaly"), (1995, "Munster", "Clare"),
    (1996, "Leinster", "Wexford"), (1997, "Munster", "Clare"), (1998, "Leinster", "Offaly"),
    (1999, "Munster", "Cork"), (2000, "Leinster", "Kilkenny"), (2001, "Munster", "Tipperary"),
    (2002, "Leinster", "Kilkenny"), (2003, "Leinster", "Kilkenny"), (2004, "Munster", "Cork"),
    (2005, "Munster", "Cork"), (2006, "Leinster", "Kilkenny"), (2007, "Leinster", "Kilkenny"),
    (2008, "Leinster", "Kilkenny"), (2009, "Leinster", "Kilkenny"), (2010, "Munster", "Tipperary"),
    (2011, "Leinster", "Kilkenny"), (2012, "Leinster", "Kilkenny"), (2013, "Munster", "Clare"),
    (2014, "Leinster", "Kilkenny"), (2015, "Leinster", "Kilkenny"), (2016, "Munster", "Tipperary"),
    (2017, "Connacht", "Galway"), (2018, "Munster", "Limerick"), (2019, "Munster", "Tipperary")]

# %% [markdown]
# Your task for part A of assignment #4 is to complete the functions ```winning_county``` and ```province_wins``` in the code cell below. Below is a transcript of the result when executing the  ```main```  provided to you with the functions completed.
# ```
# Years that Galway has won the All-Ireland: [1923, 1980, 1987, 1988, 2017]
# Years that Antrim has won the All-Ireland: []
# Number of times a team from Munster has won the All-Ireland: 73
# Number of times a team from Leinster has won the All-Ireland: 53
# Number of times a team from Ulster has won the All-Ireland: 0
# ```
#
# You need not worry whether or not the county or province entered is a real Irish county or province (i.e., no need to check for validity of the parameters in your functions).
#
# **Do not use any libraries for this assignment other than the standard library (i.e., no use of ```NumPy```, ```SciPy```, ```pandas```, etc. is permitted).** *Your functions must use `for`-loops.*

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <b>Important:</b> All functions which the assignment requires you to complete must <b>exactly match</b> the following:
#     <ul>
#         <li> the spelling of the function's name,</li>
#         <li> the number of required function parameters,</li>
#         <li> and whether or not a value must be returned.</li>
#     </ul>
#     <p>Unless otherwise required by the assignment's description, functions are not to perform input or output (i.e., are not to make calls <code>input()</code> or <code>print()</code>).</p>
# </div>

# %%
def winning_county(query_team):
    """
    function: winning_county
    
    Using a global list of tuples of the form (year, province, county)
    that corresponds to All-Ireland hurling winners since 1887, 
    and given an input parameter corresponding the county
    for which we are completing this query, the functions
    finds all years for which that county has won the Final.
    The years are returned in a list.
    
    Note that the code here may use ALL_IRELAND_WINNERS as a
    global variable (i.e., it need not be passed into the
    function as a parameter).
       
    Input:
    ------
    
    * query_county: The county name which will be used to look
      through the list of All-Ireland WInners.
      
    Output:
    --------
    
    * A (possibly empty) list of integers that are the years
      in which the query_team has won the All-Ireland Final.
    """
    
    # create an empty list to store years that the query_tem has won the All-Ireland Final
    winning_years = []
    
    # check each tuple of ALL_IRELAND_WINNERS
    for (year, province, county) in ALL_IRELAND_WINNERS:
        # check if the query_team won the game for each tuple of the list ALL_IRELAND_WINNERS
        if county == query_team:
            # add year to the list winning_years
            winning_years.append(year)

    return winning_years
    

def province_wins(query_province):
    """
    function: province_wins
    
    Using a global list of tuples of the form (year, province, county)
    that corresponds to All-Ireland hurling winners since 1888, 
    and given an input parameter corresponding the Irish province
    for which we are completing this query, the functions
    finds the number of years for a county in that province has
    won the All-Ireland Final. The result is return as an
    integer.
    
    Note that the code here may use ALL_IRELAND_WINNERS as a
    global variable (i.e., it need not be passed into the
    function as a parameter).
       
    Input:
    ------
    
    * query_province: The province name which will be used to look
      through the list of All-Ireland WInners.
      
    Output:
    --------
    
    * An integer corresponding to the number of times a county in
      that province as won the All-Ireland final.
    """
    
    # set a winning_count = 0 to use for counting the winnings of teams from the query province
    winning_count = 0
    # check each tuple of ALL_IRELAND_WINNERS
    for (year, province, county) in ALL_IRELAND_WINNERS:
        # check if a team won the game is from the query_province for each tuple of ALL_IRELAND_WINNERS
        if province == query_province:
            #add 1 to the winning_count every time there's query_province in each tuple of ALL_IRELAND_WINNERS
            winning_count += 1
        
    return winning_count

    
def main():
    print("Years that Galway has won the All-Ireland:",
         winning_county("Galway"))
    
    print("Years that Antrim has won the All-Ireland:",
         winning_county("Antrim"))
    
    print("Number of times a team from Munster has won the All-Ireland:",
          province_wins("Munster"))
    
    print("Number of times a team from Leinster has won the All-Ireland:",
          province_wins("Leinster"))
    
    print("Number of times a team from Ulster has won the All-Ireland:",
         province_wins("Ulster"))



main()
# Out:
# Years that Galway has won the All-Ireland: [1923, 1980, 1987, 1988, 2017]
# Years that Antrim has won the All-Ireland: []
# Number of times a team from Munster has won the All-Ireland: 73
# Number of times a team from Leinster has won the All-Ireland: 53
# Number of times a team from Ulster has won the All-Ireland: 0

# %% [markdown]
# ## Marks
#
# * Part A is worth 3 marks (this file)
# * Part B is worth 7 marks (in ```assign04_b.ipynb```).
# * Total for assignment: 10 marks

# %% [markdown]
# Copyright: 2020, Michael Zastre, University of Victoria, Canada
